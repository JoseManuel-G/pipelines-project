# %%
import requests
import pandas as pd
import os

# %%
token = os.getenv('token')

# %%
import requests

url = "https://tennis-live-data.p.rapidapi.com/rankings/race/ATP"

headers = {
    'x-rapidapi-key': f"token {token}",
    'x-rapidapi-host': "tennis-live-data.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers)

# %%
response.status_code # No se por que pero escondiendo el token no me sale
# Out:
# 403

# %%
import requests

url = "https://tennis-live-data.p.rapidapi.com/rankings/race/ATP"

headers = {
    'x-rapidapi-key': "", # quito la key después de haber runeado todo para que no se suba al github
    'x-rapidapi-host': "tennis-live-data.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers)

# %%
response.status_code
# Out:
# 200

# %%
data = response.json()
data
# Out:
# {'meta': {'title': 'Live Tennis API - ATP Season Race Rankings',
#   'description': 'Race to end of season rankings',
#   'fields': {'rankings_array': {'id': 'Integer - player_id',
#     'first_name': 'String',
#     'last_name': 'String',
#     'full_name': 'String',
#     'country': 'String',
#     'race_ranking': 'Integer',
#     'movement': 'String',
#     'race_points': 'Integer'}}},
#  'results': {'rankings': [{'id': 89304,
#     'first_name': 'Novak',
#     'last_name': 'Djokovic',
#     'full_name': 'Novak Djokovic',
#     'country': 'Serbia',
#     'race_ranking': 1,
#     'movement': '',
#     'race_points': 11630},
#    {'id': 100332,
#     'first_name': 'Agut',
#     'last_name': 'Bautista',
#     'full_name': 'Agut Bautista',
#     'country': 'Spain',
#     'race_ranking': 2,
#     'movement': '',
#     'race_points': 305},
#    {'id': 86928,
#     'first_name': 'Rafael',
#     'last_name': 'Nadal',
#     'full_name': 'Rafael Nadal',
#     'country': 'Spain',
# ...

# %% [markdown]
# ### Convierto la api en un DataFrame

# %%
def ranking_atp():
    results = data.get('results')
    rankings = results.get('rankings')
    df = pd.DataFrame(rankings)
    df_sort = df.sort_values(by='race_points', ascending=False, na_position='first')
    return df_sort

# %%
ranking_atp()
# Out:
#         id first_name last_name        full_name      country  race_ranking  \
# 0    89304      Novak  Djokovic   Novak Djokovic       Serbia             1
# 2    86928     Rafael     Nadal     Rafael Nadal        Spain             2
# 3   262500    Dominic     Thiem    Dominic Thiem      Austria             3
# 4   981036     Daniil  Medvedev  Daniil Medvedev       Russia             4
# 5    86064      Roger   Federer    Roger Federer  Switzerland             4
# ..     ...        ...       ...              ...          ...           ...
# 79  252918         Ji       Nam           Ji Nam  South Korea            77
# 53  283794       Juan   Londero     Juan Londero    Argentina            50
# 42  100944    Vinolas     Ramos    Vinolas Ramos        Spain            41
# 30   90552         Jo    Tsonga        Jo Tsonga       France            29
# 26  244812      Busta   Carreno    Busta Carreno        Spain            27
#
#    movement  race_points
# 0                  11630
# ...

# %%
ranking_atp().to_csv('ranking_atp().csv')
